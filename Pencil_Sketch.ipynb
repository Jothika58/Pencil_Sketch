# %%
from google.colab.patches import cv2_imshow

# %%
import cv2

# %%
img=cv2.imread('/content/Jeff.jpeg')

# %%
gray_image=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

# %%
inverted_image=255-gray_image

# %%
blurred=cv2.GaussianBlur(inverted_image,(21,21),5)

# %%
inverted_blurred=255-blurred

# %%
pencil_sketch = cv2.divide(gray_image,inverted_blurred,scale=256.0)

# %%
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=1080x1037 at 0x7F493D6745D0>

# %%
cv2_imshow(pencil_sketch)
# Out:
# <PIL.Image.Image image mode=L size=1080x1037 at 0x7F493CEEEE50>
